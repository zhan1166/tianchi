# %% [markdown]
# ## 天池 Task01

# %% [markdown]
# **这里简单记录一下心得体会**

# %% [markdown]
# ### 1. Docker 的使用有点像服务器，但是又有些不同。服务器跑程序的时候需要划出内存空间来配置操作系统，但是docker不用。

# %% [markdown]
# ### 2. 文件上传需要几个基础文件 并放置在统一的文件夹下

# %% [markdown]
# 1) python 脚本
#
# 注意事项：
#
# a. 需要 #!/usr/bin/env python 申明
#
# b. 文件地址"/tcdata/num_list"

# %% [markdown]
# 2) requirements.txt python调包的版本声明
#
# 例如：
#
# pandas==0.25.1
#
# numpy==1.19.4

# %% [markdown]
# 3) run.sh shell脚本
#
# #!/bin/sh
#
# python hello_world.py

# %% [markdown]
# 4) Dockerfile
#
# \# Base Images
# \## 从天池基础镜像构建
#
# FROM registry.cn-shanghai.aliyuncs.com/tcc-public/python:3
#
# \## 把当前文件夹里的文件构建到镜像的根目录下
#
# ADD . /
#
# \## 指定默认工作目录为根目录（需要把run.sh和生成的结果文件都放在该文件夹下，提交后才能运行）
#
# WORKDIR /
#
# RUN pip install -i https://pypi.tuna.tsinghua.edu.cn/simple -r requirements.txt
#
# \## 镜像启动后统一执行 sh run.sh
#
# CMD ["sh", "run.sh"]

# %% [markdown]
# ### 3. docker 的基本操作使用命令

# %% [markdown]
# 1) 登录仓库
#
# docker login --username=我的用户名 我的仓库地址

# %% [markdown]
# 2) 建造镜像
#
# docker build -t registry.我的仓库地址:版本 .
#
# 最后一定要加上：空格+.

# %% [markdown]
# 3) run镜像
#
# docker run registry.我的仓库地址:版本

# %% [markdown]
# 4) push镜像
#
# docker push registry.我的仓库地址:版本

# %% [markdown]
# 5)提交作业

# %% [markdown]
# ### 4. 我的成绩

# %% [markdown]
# ![image.png](attachment:image.png)
